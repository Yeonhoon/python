# %%
list1 = ['종하','성진','지원','성훈','근영','현욱','승훈', '재서','용식','재호','유진','혜민','해민','용상','인수','준혁','준우']
list2 = ['유빈쌤','신경쌤','지연쌤','민정쌤','강희쌤','은지쌤','민주쌤','세린쌤']
list3 = ['유명순 교수님', '차량반장님','천선아 선생님','서병로 교수님','신수정 선생님']
sen = "아 잘사냐~ 새해복 많이 받아라!!"
friends=[]
high = []
higher = []

for i in range(len(list1)):
    friends.append(list1[i] + sen)
    high.append(list2[i] + sen)
    higher.append(list3[i] + sen)
    
np.vstack(friends)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-201-fa7e54eca93c> in <module>
#      10     friends.append(list1[i] + sen)
#      11     high.append(list2[i] + sen)
# ---> 12     higher.append(list3[i] + sen)
#      13
#      14 np.vstack(friends)
#
# IndexError: list index out of range

# %%
len(lists)
# Out:
# 9

# %%
import numpy as np
x_vertical=np.vstack(x)
x_hori = np.row_stack(x_vertical)
x_hori
# Out:
# array([['장연훈아 메리 크리스마스~ 해피 뉴이어~ 그리고 새해복 많이 받아!!'],
#        ['홍미령아 메리 크리스마스~ 해피 뉴이어~ 그리고 새해복 많이 받아!!']], dtype='<U38')

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import pandas_datareader.data as web
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from fbprophet import Prophet

from datetime import datetime

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus']=False

if platform.system() == "Windows":
    path = "C:\Windows\Fonts/NanumGothic.ttf"
    font_name = font_manager.FontProperties(fname = path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown System...')
# %matplotlib inline

# %%
web_t = pd.read_csv('data/web_traffic.csv',encoding='utf-8')

x=str(list(web_t['date']))
x2=x.split('\\t')

x2[1]
x3= []
x4= []
for i in range(len(x2)):
    x3.append(x2[i].split('\\n'))
    x4.append(x3[i][0])

hits = x4[1:]
hits[364] = '1193'

hit= []
for i in range(len(hits)):
    hit.append(float(hits[i].replace(',','')))

# %%
date = pd.date_range(start='2016-07-01', end='2017-06-30', freq='D')
len(date)

traffic = pd.DataFrame({'date':date, 'hits':hit})
traffic['date']
# Out:
# 0     2016-07-01
# 1     2016-07-02
# 2     2016-07-03
# 3     2016-07-04
# 4     2016-07-05
#          ...
# 360   2017-06-26
# 361   2017-06-27
# 362   2017-06-28
# 363   2017-06-29
# 364   2017-06-30
# Name: date, Length: 365, dtype: datetime64[ns]

# %%
traffic['hits'].plot(figsize = (12,4), grid=True)
# Out:
# <AxesSubplot:>
